# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
# 1.1 Load the "iris" dataset into a pandas DataFrame and sort the rows
# by the "sepal_length" column in ascending order.

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df_iris = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])

# %%
sorted_df_iris = df_iris.sort_values(by='sepal length (cm)', ascending=True)

# %%
sorted_df_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
plt.plot(sorted_df_iris)
plt.show()

# %%
# 1.2 Load the "titanic" dataset into a pandas DataFrame and
# filter out passengers who were younger than 18 years old.

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
filtered_titanic = titanic[titanic['age'] >= 8]

# %%
filtered_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
filtered_titanic_female = titanic[titanic['sex'] == 'female']['age']

# %%
filtered_titanic_female
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# 888     NaN
# Name: age, Length: 314, dtype: float64

# %%
plt.plot(filtered_titanic_female)
plt.xlabel('Passenger Number of Female')
plt.ylabel('Age of Female')
plt.show()

# %%
# 1.3 Load the "wine_quality" dataset into a pandas DataFrame and
# select only the rows where the "quality" column is greater than or equal to 7.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

# %%
wine = pd.read_csv(url, sep=';')

# %%
wine_quality = wine[wine['quality'] >= 7]

# %%
wine_quality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 37              8.1              0.38         0.28             2.1      0.066
# 62              7.5              0.52         0.16             1.9      0.085
# ...             ...               ...          ...             ...        ...
# 1541            7.4              0.25         0.29             2.2      0.054
# 1544            8.4              0.37         0.43             2.3      0.063
# 1549            7.4              0.36         0.30             1.8      0.074
# 1555            7.0              0.56         0.17             1.7      0.065
# 1584            6.7              0.32         0.44             2.4      0.061
#
# ...

# %%
plt.plot(wine_quality, label=wine_quality.columns)
plt.legend()
plt.show()

# %%
# 1.4 Load the "covid_worldwide.csv" dataset into a pandas DataFrame and
# create a new DataFrame that only contains the columns "Country", "Total Cases",
# "Total Recovered", and "Population".

# %%
covid_data = pd.read_csv('covid_worldwide.csv', index_col='Country')

# %%
covid_data.drop('Serial Number', axis=1)
# Out:
#                   Total Cases Total Deaths Total Recovered Active Cases  \
# Country
# USA               104,196,861    1,132,935     101,322,779    1,741,147
# India              44,682,784      530,740      44,150,289        1,755
# France             39,524,311      164,233      39,264,546       95,532
# Germany            37,779,833      165,711      37,398,100      216,022
# Brazil             36,824,580      697,074      35,919,372      208,134
# ...                       ...          ...             ...          ...
# Diamond Princess          712           13             699            0
# Vatican City               29          NaN              29            0
# Western Sahara             10            1               9            0
# MS Zaandam                  9            2               7            0
# Tokelau                     5          NaN             NaN            5
#
#                      Total Test     Population
# Country
# ...

# %%
covid_filtered = covid_data[["Total Cases",
                             "Total Recovered",
                             "Population"]]

# %%
covid_filtered
# Out:
#                   Total Cases Total Recovered     Population
# Country
# USA               104,196,861     101,322,779    334,805,269
# India              44,682,784      44,150,289  1,406,631,776
# France             39,524,311      39,264,546     65,584,518
# Germany            37,779,833      37,398,100     83,883,596
# Brazil             36,824,580      35,919,372    215,353,593
# ...                       ...             ...            ...
# Diamond Princess          712             699            NaN
# Vatican City               29              29            799
# Western Sahara             10               9        626,161
# MS Zaandam                  9               7            NaN
# Tokelau                     5             NaN          1,378
#
# [231 rows x 3 columns]

# %%
# 1.5 Load the "diamonds.csv" dataset into a pandas DataFrame and group the rows
# by the "carat" column, and then calculate the mean value of the "price"
# column for each group.

# %%
diamond_data = pd.read_csv('diamonds.csv')

# %%
diamond_data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
diamond_group = diamond_data.groupby('carat')['price'].mean(numeric_only=True)

# %%
diamond_group
# Out:
# carat
# 0.20      365.166667
# 0.21      380.222222
# 0.22      391.400000
# 0.23      486.143345
# 0.24      505.185039
#             ...
# 4.00    15984.000000
# 4.01    15223.000000
# 4.13    17329.000000
# 4.50    18531.000000
# 5.01    18018.000000
# Name: price, Length: 273, dtype: float64

# %%
plt.plot(diamond_group)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# 1.6 Load the "titanic" dataset into a pandas DataFrame and
# create a new DataFrame that only contains the columns "survived", "sex", and "age".

# %%
titanic_data = sns.load_dataset('titanic')

# %%
titanic_filtered = titanic_data[['survived', 'sex', 'age']]

# %%
titanic_filtered
# Out:
#      survived     sex   age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %%
# 1.7 Load the "diamond" dataset into a pandas DataFrame and create a new DataFrame
# that only contains the rows where the "carat" column is greater than or equal to 0.5.

# %%
diamond_data[diamond_data['carat'] >= 0.5]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 90             91   0.70      Ideal     E     SI1   62.5   57.0   2757  5.70
# 91             92   0.86       Fair     E     SI2   55.1   69.0   2757  6.45
# 92             93   0.70      Ideal     G     VS2   61.6   56.0   2757  5.70
# 93             94   0.71  Very Good     E     VS2   62.4   57.0   2759  5.68
# 94             95   0.78  Very Good     G     SI2   63.8   56.0   2759  5.81
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 90     5.72  3.57
# ...

# %%
# 1.8 Load the "titanic" dataset into a pandas DataFrame and create a
# bar chart showing the number of passengers who survived and the
# number who did not survive, grouped by the "sex" column.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_group = titanic.groupby(['sex', 'survived'])['survived'].count()

# %%
titanic_group
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
titanic_group.plot(kind='bar')
plt.show()

# %%
# 1.9 Load the "iris" dataset into a pandas DataFrame and create a
# scatter plot showing the relationship between the "sepal_length"
# and "sepal_width" columns, with different colors for each species of iris.

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df_iris = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])

# %%
df_iris['target'] = iris['target']

# %%
colors = ['red', 'green', 'blue']

# %%
for i in range(len(iris['target_names'])):
    plt.scatter(df_iris[df_iris['target'] == i]['sepal length (cm)'],
                df_iris[df_iris['target'] == i]['sepal width (cm)'],
                c=colors[i],
                label=iris['target_names'][i])
plt.legend()
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
# 1.10 Load the "diamonds" dataset into a pandas DataFrame and
# create a box plot showing the distribution of the "price" column,
# grouped by the "cut" column.

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.boxplot(x='cut', y='price', data=diamonds)
plt.show()
